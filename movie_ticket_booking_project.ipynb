# %%
def first():
    
    def ticket():
        print("\n\n--------------------------------")
        print("  TICKET BOOKING")
        print("   JAAT CINEMA")
        print("MOVIE NAME :",l4[0])
        print("SHOW TIME  :",l5[0])
        print("SEAT TYPE  :",l2[a-1])
        print("TOTAL SEATS:",b)
        print("TOTAL PRICE:",t_price)
        print("    THANK YOU")
        print("--------------------------------")
        #ticket()
    
    l1=["9AM-1PM","2PM-6PM","8PM-12AM"]
    
    print("MOVIES according to  your time ")
    
    l = ["STREE 2","JOKER","VENOM"]
    
    for k in l:
        print(k)
        
    print("\nchoose (1,2,3)")
    
    a = int(input("Enter your number"))
    global t_price
    
    if a == 1:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choosed",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("\nWHICH TYPE OF SEAT YOU WANT")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=200
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 350
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
                    
            
    elif a == 2:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=200
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 400
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
    elif a == 3:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 350
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 400
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
            
def second():
    
    def ticket():
        print("\n\n--------------------------------")
        print("  TICKET BOOKING")
        print("   JAAT CINEMA")
        print("MOVIE NAME :",l4[0])
        print("SHOW TIME  :",l5[0])
        print("SEAT TYPE  :",l2[a-1])
        print("TOTAL SEATS:",b)
        print("TOTAL PRICE:",t_price)
        print("    THANK YOU")
        print("--------------------------------")
    
    l1=["9AM-1PM","2PM-6PM","8PM-12AM"]
    global t_price
    print("MOVIES according to  your time ")
    
    l = ["STREE 2","VENOM","KING KONG"]
    
    for k in l:
        print(k)
        
    print("choose (1,2,3)")
    
    a = int(input("Enter your number"))
    
    if a == 1:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=200
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 350
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
                    
            
    elif a == 2:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 350
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 400
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
    elif a == 3:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=150
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 200
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
            
def third():
    
    def ticket():
        print("\n\n--------------------------------")
        print("  TICKET BOOKING")
        print("   JAAT CINEMA")
        print("MOVIE NAME :",l4[0])
        print("SHOW TIME  :",l5[0])
        print("SEAT TYPE  :",l2[a-1])
        print("TOTAL SEATS:",b)
        print("TOTAL PRICE:",t_price)
        print("    THANK YOU")
        print("--------------------------------")
    
    l1=["9AM-1PM","2PM-6PM","8PM-12AM"]
    global t_price
    print("MOVIES according to  your time ")
    
    l = ["DEVIL","JOKER","NO TIME TO DIE"]
    
    for k in l:
        print(k)
        
    print("choose (1,2,3)")
    
    a = int(input("Enter your number"))
    
    if a == 1:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=200
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 350
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
                    
            
    elif a == 2:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=200
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 300
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 400
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
    elif a == 3:
        l5=[]
        l5.append(l1[a-1])
        l4=[]
        print("You choose",l[a-1])
        l4.append(l[a-1])
        print(l4)
        print("Seats availeble")
        l2 = ["Silver","Gold","ClubSofa","Platinum"]
        for k in l2:
            print(k)
        a = int(input("Enter the type of seat(1,2,3,4)"))
        if a == 1:
            print("you select the",l2[a-1],"type of seat")
            price=250
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
            #print(l4)
        elif a == 2:
            print("you select the",l2[a-1],"type of seat")
            price = 350
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            print(l4)
            ticket()
        elif a == 3:
            print("you select the",l2[a-1],"type of seat")
            price = 400
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        elif a == 4:
            print("you select the",l2[a-1],"type of seat")
            price = 450
            b = int(input("Enter number of seats you want"))
            t_price = price*b
            print("Total Price",t_price)
            ticket()
        else: 
            print("Enter a valid number between (1,2,3,4)")
            

def main():
    print("    WELCOME TO TICKET BOOKING")
    print("\nWe have 3 shows a day which you want choose according to your time")
    l1=["9AM-1PM","2PM-6PM","8PM-12AM"]
    
    for k in l1:
        print(k)
    print("\nchoose (1,2,3)")
    a=int(input("Enter your number"))
    if a==1:
        first()
    elif a==2:
        second()
    elif a==3:
        third()
    else:
        print("please! Enter a valid number")
        print("THANK YOU")
main() 

ip=input("What you want to order something(y/n):")
ip=ip.lower()
l10=[]
if ip=="y":
    l9=[]
    l10=[]
    l11=[]
    while True:
        import pandas as pd
        l6=["Popcorn","Nachos","Candy","Water","Orange Juice","Cheesecake Bites"]
        l7=[90,150,70,50,60,200]
        d1={"FOOD":l6,"PRICE":l7}
        df=pd.DataFrame(d1)
        
        print(df)
        q=int(input("Enter number what you want(0,1,2,3,4,5):")) 
        if q==0:
            u=int(input("enter quantity:"))
            price=l7[q]
            l9.append(l6[q])
            l10.append(price*u)
            l11.append(u)
              
        elif q==1:
            u=int(input("enter quantity:"))
            price=l7[q]
            l9.append(l6[q])
            l10.append(price*u)
            l11.append(u)
        elif q==2:
            u=int(input("enter quantity:"))
            price=l7[q]
            l9.append(l6[q])
            l10.append(price*u)
            l11.append(u)
        elif q==3:
            u=int(input("enter quantity:"))
            price=l7[q]
            l9.append(l6[q])
            l10.append(price*u)
            l11.append(u)
            
        elif q==4:
            u=int(input("enter quantity:"))
            price=l7[q]
            l9.append(l6[q])
            l10.append(price*u)
            l11.append(u)
            
        elif q==5:
            u=int(input("enter quantity:"))
            price=l7[q]
            l9.append(l6[q])
            l10.append(price*u)
            l11.append(u)
            
            
        else:
            print("please enter number from 0 to 5")
            
        d2={"FOOD":l9,"QUANTITY":l11,"PRICE":l10}   
        df2=pd.DataFrame(d2) 
        print("\nyour ordered item list")
        print(df2)
        w=input  ("you want to order food(y/n)") 
        w=w.lower()
        if w=="y":
            continue
        else:
            break
    
    else:
        print("THANK YOU")
else:
    print("THANK YOU")
    
total_price=t_price+(sum(l10))
print("Totol Amount You Need To Pay",total_price)
# Out:
#     WELCOME TO TICKET BOOKING
#
# We have 3 shows a day which you want choose according to your time
# 9AM-1PM
# 2PM-6PM
# 8PM-12AM
#
# choose (1,2,3)
# Enter your number2
# MOVIES according to  your time
# STREE 2
# VENOM
# KING KONG
# choose (1,2,3)
# Enter your number3
# You choose KING KONG
# ['KING KONG']
# Seats availeble
# Silver
# Gold
# ClubSofa
# Platinum
# Enter the type of seat(1,2,3,4)4
# you select the Platinum type of seat
# Enter number of seats you want3
# Total Price 900
#
#
# --------------------------------
#   TICKET BOOKING
#    JAAT CINEMA
# MOVIE NAME : KING KONG
# SHOW TIME  : 8PM-12AM
# SEAT TYPE  : Platinum
# TOTAL SEATS: 3
# TOTAL PRICE: 900
#     THANK YOU
# --------------------------------
# What you want to order something(y/n):3
# THANK YOU
# Totol Amount You Need To Pay 900
